# %%
conda install pytube3
pip install pytube3

# %%
from pytube import YouTube

# %%
URL = input("Write your link : ")
yt = YouTube(url = URL)

# %%
#Get the video describtion
yt.describtion

# %%
#Get the number of views
yt.views

# %%
#Get the length of video ( in Seconds)
yt.length

# %%
#Get the video rating
yt.rating

# %%
yt.download()
